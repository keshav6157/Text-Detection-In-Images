# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt
# Out:
# c:\users\keshav anand\appdata\local\programs\python\python37\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\keshav anand\appdata\local\programs\python\python37\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
# c:\users\keshav anand\appdata\local\programs\python\python37\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
img = cv2.imread('demo2.jpg')
plt.imshow(img)

# %%
img2char = pytesseract.image_to_string(img)

# %%
print(img2char)
# Out:
# YOU'RE NOT LOST
#
# YOU'RE HERE

# %%
imgbox = pytesseract.image_to_boxes(img)
print(imgbox)
# Out:
# Y 1719 2037 1886 2173 0
# O 1892 2033 2050 2172 0
# U 2083 2031 2234 2169 0
# ' 2271 2109 2320 2167 0
# R 2353 2031 2496 2167 0
# E 2534 2029 2665 2165 0
# N 2786 2028 2934 2163 0
# O 2969 2025 3125 2163 0
# T 3143 2025 3284 2161 0
# L 3400 2023 3526 2158 0
# O 3543 2020 3699 2158 0
# S 3727 2019 3864 2157 0
# T 3882 2020 4024 2154 0
# Y 1992 1713 2160 1853 0
# O 2169 1710 2330 1854 0
# U 2363 1708 2515 1851 0
# ' 2554 1789 2602 1849 0
# R 2638 1708 2784 1848 0
# E 2822 1707 2957 1847 0
# H 3077 1705 3231 1845 0
# E 3269 1703 3407 1844 0
# R 3439 1702 3589 1842 0
# E 3621 1700 3760 1841 0
# ~ 1214 1283 4516 2541 0

# %%
type(imgbox)
# Out:
# str

# %%
imgH, imgW,_ = img.shape

# %%
img.shape
# Out:
# (3871, 5806, 3)

# %%
for boxes in imgbox.splitlines():
    boxes = boxes.split(' ')
    x,y,w,h = int(boxes[1]), int(boxes[2]), int(boxes[3]), int(boxes[4])
    cv2.rectangle(img, (x, imgH-y), (w, imgH-h), (0,0,255), 10)

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
